# %% [markdown]
# # raft-lm RunPod Training
#
# Interactive notebook variant for RunPod GPU pods.

# %%
import subprocess
from pathlib import Path

repo = Path.cwd()
subprocess.run(["bash", "runpod/setup.sh"], cwd=repo, check=True)

# %%
import subprocess
import sys
from pathlib import Path

repo = Path.cwd()
proc = subprocess.Popen(
    [sys.executable, "runpod/train.py", "--config", "runpod/config.yaml"],
    cwd=repo,
)
proc.wait()
